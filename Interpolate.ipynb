# %%
import pandas as pd

# %%
df = pd.read_csv('D:\\New folder\\Fortune_10.csv')
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4              NaN          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7              NaN               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1    916,455 Dollars  11412916.0    NaN
# 2  7,591,189 Dollars   3005820.0     7%
# 3  7,429,377 Dollars   6597557.0    26%
# ...

# %%
df.interpolate()
# Out:
# C:\Users\Khan Gadget\AppData\Local\Temp\ipykernel_7580\4002874584.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4              NaN          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7              NaN               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# ...

# %%
df.interpolate(method = 'time')
# Out:
# C:\Users\Khan Gadget\AppData\Local\Temp\ipykernel_7580\3099140417.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method = 'time')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.interpolate(method = 'time')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:8206, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8204 else:
#    8205     index = missing.get_interp_index(method, obj.index)
# -> 8206     new_data = obj._mgr.interpolate(
#    8207         method=method,
#    8208         index=index,
#    8209         limit=limit,
#    8210         limit_direction=limit_direction,
# ...

# %%
df = pd.read_csv('D:\\New folder\\student_results.csv')
df

# %%
type(df.Date[0])

# %%
df = pd.read_csv('D:\\New folder\\student_results.csv', parse_dates = ['Date'])
df

# %%
type(df.Date[0])

# %%
df.interpolate(method = 'time')

# %%
df = pd.read_csv('D:\\New folder\\student_results.csv', parse_dates = ['Date'], index_col = 'Date')
df

# %%
df.interpolate(method= 'time')

# %%
df.interpolate()

# %%
df.loc[0]
# Out:
# ID                           1
# Name                   Lamtone
# Industry           IT Services
# Inception                 2009
# Revenue           $11,757,018
# Expenses     6,482,465 Dollars
# Profit               5274553.0
# Growth                     30%
# Name: 0, dtype: object

# %%
df.loc[[0,1,5]]
# Out:
#    ID       Name            Industry  Inception       Revenue  \
# 0   1    Lamtone         IT Services       2009  $11,757,018
# 1   2  Stripfind  Financial Services       2010  $12,329,371
# 5   6   Techline              Health       2006  $13,898,119
#
#             Expenses      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1    916,455 Dollars  11412916.0    NaN
# 5  5,470,303 Dollars   8427816.0    23%
